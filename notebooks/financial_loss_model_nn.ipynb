# %% [markdown]
# # Modeling Financial Loss
# Two models used:
# 1. Linear regression
# 2. Neural Network with MSE loss and standardized for training
#
# Next steps:
# - Feature engineering: find and exclude near-constant or dependent features
# - Exclude input variables that wouldn't be known at time of prediction
# - Random Forest / XGBoost

# %%
import pandas as pd
import numpy as np
import torch 
from torch import nn
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import sys
from tqdm import tqdm
from sklearn.model_selection import train_test_split

# %%
data_directory = "../Data/unh_hackathon_prompt_2_data.json"
sys.path.append("../UNH-Hackathon-2026-Group-3/")

# %% [markdown]
# ## preparing the data

# %%
def load_predictive_warfighting_data(file_path: str = "unh_hackathon_prompt_2_data.json") -> pd.DataFrame:
    """Load data from a CSV file into a pandas DataFrame."""
    return pd.read_json(file_path)

dirty_df = load_predictive_warfighting_data(data_directory)

# print data types of each column
# print(dirty_df.dtypes)

# %%
def clean_data(df: pd.DataFrame) -> pd.DataFrame:
    """Clean the DataFrame by converting data types."""

    # Convert the string "NULL" to pd.NA
    df = df.replace("NULL", pd.NA)
    df = df.replace("N/A", pd.NA)

    for numeric_string_column in [
        "Enemy.Capability.Index",
        "EW_Capability",
        "Intel Confidence",

    ]:
        df[numeric_string_column] = pd.to_numeric(df[numeric_string_column])

    for boolean_string_column in [
        "response_success"
    ]:
        df[boolean_string_column] = df[boolean_string_column].map({"Yes": 1, "No": 0, "1": 1, "0": 0})

    return df

df = clean_data(dirty_df)

# get unique values for each string column, and min/max for each numeric column
for column in df.columns:
    if df.dtypes[column] == "str":
        print(f"Values: {df[column].drop_duplicates()}")
    else: 
        print(f"Name: {column}, dtype: {df.dtypes[column]}, min: {df[column].min()}, max: {df[column].max()}")

print(f"number of rows: {len(df)}")     
df.head()
# Out:
# Values: 0       Missile
# 2           Air
# 3         Cyber
# 4        Hybrid
# 7         Naval
# 14          AIR
# 35        CYBER
# 39       Hybrid
# 43          Msl
# 79        naval
# 119       Cyber
# 239         AIR
# 279         Air
# 299       naval
# 319     Missile
# Name: Threat Type, dtype: str
# Name: enemy_unit_count, dtype: int64, min: 1, max: 50
# Name: Enemy.Capability.Index, dtype: int64, min: 1, max: 10
# Name: ThreatEscalationHours, dtype: int64, min: 1, max: 72
# Name: friendlyUnitCount, dtype: int64, min: 5, max: 60
# Name: LCS_COUNT, dtype: int64, min: 0, max: 8
# Name: Aircraft Count, dtype: int64, min: 0, max: 24
# Name: cyber_defense_teams, dtype: int64, min: 0, max: 12
# Name: Patriot.Batteries, dtype: int64, min: 0, max: 6
# Name: ISR_AssetCount, dtype: int64, min: 0, max: 15
# Name: satellite coverage score, dtype: float64, min: 0.2, max: 1.0
# Name: JointForceIntegration, dtype: int64, min: 1, max: 10
# Name: EW_Capability, dtype: float64, min: 0.0, max: 10.0
# Name: Supply Chain Resilience, dtype: float64, min: 0.4, max: 1.0
# Name: PriorEngagements, dtype: int64, min: 0, max: 25
# Name: force_readiness_score, dtype: int64, min: 40, max: 100
# Name: Intel Confidence, dtype: float64, min: 0.3, max: 1.0
# Name: ResponseTime_hrs, dtype: int64, min: 1, max: 48
# Name: logistics_delay_hours, dtype: int64, min: 0, max: 24
# Name: CMD_COORD_SCORE, dtype: int64, min: 1, max: 10
# Name: roe_complexity_score, dtype: int64, min: 1, max: 5
# Name: Operational Budget (MUSD), dtype: int64, min: 50, max: 500
# Name: BudgetUtilization_pct, dtype: int64, min: 60, max: 100
# Name: Weather_Severity, dtype: int64, min: 0, max: 10
# Name: Theater Distance KM, dtype: float64, min: 504.9, max: 9997.0
# Values: 0        Winter
# 1          Fall
# 4        Spring
# 7        Summer
# 24       spring
# 34        Fall
# 69      Winter
# 104     Summer
# 111      Autumn
# 119      SUMMER
# 139     Spring
# 174     spring
# 559     Autumn
# 1889    SUMMER
# Name: Season, dtype: str
# Name: response_success, dtype: int64, min: 0, max: 1
# Name: Financial_Loss_MUSD, dtype: int64, min: 63, max: 658
# Name: actual_days_to_stabilization, dtype: float64, min: 2.0, max: 28.2
# number of rows: 3000
#   Threat Type  enemy_unit_count  Enemy.Capability.Index  \
# 0     Missile                25                       8
# 1     Missile                 3                       2
# 2         Air                 7                       3
# 3       Cyber                31                       7
# 4      Hybrid                14                       5
#
#    ThreatEscalationHours  friendlyUnitCount  LCS_COUNT  Aircraft Count  \
# 0                     34                 21          0               0
# 1                      8                 45          0               0
# 2                     48                 45          0               5
# 3                     70                 57          0               0
# 4                     27                 57          0               0
#
#    cyber_defense_teams  Patriot.Batteries  ISR_AssetCount  ...  \
# 0                    0                  4              12  ...
# 1                    0                  4               4  ...
# 2                    0                  0              14  ...
# 3                    7                  0               5  ...
# 4                    0                  0              10  ...
#
#    CMD_COORD_SCORE  roe_complexity_score  Operational Budget (MUSD)  \
# 0                7                     3                         98
# 1                9                     5                        189
# 2                9                     1                         92
# 3               10                     3                        314
# 4                6                     4                        290
#
#    BudgetUtilization_pct  Weather_Severity  Theater Distance KM  Season  \
# 0                     84                 3               5164.8  Winter
# 1                     97                 1               7149.7    Fall
# 2                     88                 0               6706.5  Winter
# 3                     86                 9               1851.9    Fall
# 4                     84                 4                983.7  Spring
#
#    response_success  Financial_Loss_MUSD  actual_days_to_stabilization
# 0                 1                  388                          10.1
# 1                 1                  244                           2.0
# 2                 1                  280                           2.0
# 3                 1                  330                           5.3
# 4                 1                  240                          11.0
#
# [5 rows x 29 columns]

# %%
# get count of rows for each threat type 
threat_type_counts = df["Threat Type"].value_counts()
threat_type_counts
# Out:
# Threat Type
# Naval       741
# Air         684
# Hybrid      557
# Cyber       425
# Missile     408
# AIR          42
# CYBER        32
# Msl          21
#  naval       19
#  Hybrid      15
# naval        15
#  Cyber       13
#  Missile     13
#  Air         10
#  AIR          5
# Name: count, dtype: int64

# %%
# combine "Naval", "  naval", and "naval" into same category 
df["Threat Type"] = df["Threat Type"].str.strip()  # Remove leading/trailing whitespace
df["Threat Type"] = df["Threat Type"].str.lower()  # Convert to lowercase for consistency

# combine missile and msl into same threat type 
df["Threat Type"] = df["Threat Type"].replace({"msl": "missile"})

threat_type_counts = df["Threat Type"].value_counts()
threat_type_counts
# Out:
# Threat Type
# naval      775
# air        741
# hybrid     572
# cyber      470
# missile    442
# Name: count, dtype: int64

# %%
# filter by threat type here 
# df = df[df["Threat Type"] == "air"]

# %%
# remove rows with nan values in any column 
df = df.dropna()
len(df)
# Out:
# 2945

# %%
# get array of values for input variables:
''' 
every column except output/results and categorical variables 
- also remove columns with nan values 
'''
input_columns = df.select_dtypes(include=[np.number]).columns.tolist()
input_columns.remove('response_success')
input_columns.remove('Financial_Loss_MUSD')
input_columns.remove('actual_days_to_stabilization')
input_columns = [col for col in input_columns if not df[col].isna().any()]
inputs = df[input_columns].values


# get array of values for output variables:
'''
response_success, dtype: int64
Financial_Loss_MUSD, dtype: int64
actual_days_to_stabilization, dtype: float64
'''
response_successes = df['response_success'].values
financial_loss_musds = df['Financial_Loss_MUSD'].values
actual_days_to_stabilizations = df['actual_days_to_stabilization'].values

output = financial_loss_musds

len(inputs[0]), inputs[0:3], output[0:3]
# Out:
# (24,
#  array([[2.5000e+01, 8.0000e+00, 3.4000e+01, 2.1000e+01, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 4.0000e+00, 1.2000e+01, 5.9000e-01,
#          3.0000e+00, 2.0000e+00, 4.9000e-01, 1.8000e+01, 6.9000e+01,
#          8.2000e-01, 2.9000e+01, 2.4000e+01, 7.0000e+00, 3.0000e+00,
#          9.8000e+01, 8.4000e+01, 3.0000e+00, 5.1648e+03],
#         [3.0000e+00, 2.0000e+00, 8.0000e+00, 4.5000e+01, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 4.0000e+00, 4.0000e+00, 5.5000e-01,
#          9.0000e+00, 6.0000e+00, 9.4000e-01, 1.3000e+01, 6.2000e+01,
#          8.5000e-01, 4.7000e+01, 7.0000e+00, 9.0000e+00, 5.0000e+00,
#          1.8900e+02, 9.7000e+01, 1.0000e+00, 7.1497e+03],
#         [7.0000e+00, 3.0000e+00, 4.8000e+01, 4.5000e+01, 0.0000e+00,
#          5.0000e+00, 0.0000e+00, 0.0000e+00, 1.4000e+01, 8.8000e-01,
#          3.0000e+00, 1.0000e+00, 6.3000e-01, 2.0000e+00, 1.0000e+02,
#          8.1000e-01, 3.6000e+01, 3.0000e+00, 9.0000e+00, 1.0000e+00,
#          9.2000e+01, 8.8000e+01, 0.0000e+00, 6.7065e+03]]),
#  array([388, 244, 280]))

# %%
# plot input vs output for some input variables
input_names = [
    'satellite coverage score',
    'enemy_unit_count',
    'Enemy.Capability.Index',
    'Theater Distance KM'
]
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.flatten()

for i, ax in enumerate(axes):
    ax.scatter(df[input_names[i]], output, s=2)
    ax.set_xlabel(input_names[i])
    ax.set_ylabel("Financial Loss (normalized)")
    ax.set_title(f"{input_names[i]} vs Financial Loss")

# %%
# histogram for some input variables
input_names = [
    'satellite coverage score',
    'enemy_unit_count',
    'Enemy.Capability.Index',
    'Theater Distance KM'
]
fig, axes = plt.subplots(2, 2, figsize=(10, 5))
axes = axes.flatten()

for i, ax in enumerate(axes):
    ax.hist(df[input_names[i]], bins=30, alpha=0.7)
    ax.set_xlabel(input_names[i])
    ax.set_ylabel("Frequency")
    ax.set_title(f"{input_names[i]} Distribution")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## preparing + running the model to predict financial loss

# %%
# visualize the distribution 
plt.hist(financial_loss_musds, bins=50)
plt.xlabel("Financial Loss (MUSD)")
plt.ylabel("Frequency")
plt.title("Distribution of Financial Loss")
plt.show()

# %%
# scikit learn train test split implementation 
inputs_train, inputs_test, output_train, output_test = train_test_split(
    inputs, output, test_size=0.2, random_state=42)

inputs_train[0], output_train[0]
# Out:
# (array([3.0000e+01, 5.0000e+00, 2.9000e+01, 5.7000e+01, 0.0000e+00,
#         0.0000e+00, 2.0000e+00, 0.0000e+00, 1.0000e+01, 5.7000e-01,
#         1.0000e+00, 5.0000e+00, 4.4000e-01, 2.4000e+01, 8.1000e+01,
#         9.7000e-01, 4.5000e+01, 1.0000e+00, 1.0000e+01, 3.0000e+00,
#         5.4000e+01, 8.3000e+01, 0.0000e+00, 5.2534e+03]),
#  np.int64(296))

# %%
# standardize 
train_input_means = np.mean(inputs_train, axis=0)
train_input_stds = np.std(inputs_train, axis=0)
inputs_train = (inputs_train - train_input_means) / (train_input_stds + 1e-8)
inputs_test = (inputs_test - train_input_means) / (train_input_stds + 1e-8)

train_output_mean = np.mean(output_train)
train_output_std = np.std(output_train)
output_train = (output_train - train_output_mean) / (train_output_std + 1e-8)
output_test = (output_test - train_output_mean) / (train_output_std + 1e-8)

inputs_train[0], output_train[0]
# Out:
# (array([ 0.30668271, -0.19667566, -0.39783589,  1.53510575, -0.47909972,
#         -0.49471853,  0.37837363, -0.33682718,  0.60204725, -0.14561976,
#         -1.58130083, -0.044019  , -1.48553301,  1.50385373,  0.62057173,
#          1.60341588,  1.46994105, -1.58287932,  1.56033253,  0.0205849 ,
#         -1.65892897,  0.26791034, -1.57632656, -0.00176667]),
#  np.float64(-0.1925269864168591))

# %% [markdown]
# # linear regression

# %%
torch.Tensor(inputs_train)[0]
# Out:
# tensor([ 0.3067, -0.1967, -0.3978,  1.5351, -0.4791, -0.4947,  0.3784, -0.3368,
#          0.6020, -0.1456, -1.5813, -0.0440, -1.4855,  1.5039,  0.6206,  1.6034,
#          1.4699, -1.5829,  1.5603,  0.0206, -1.6589,  0.2679, -1.5763, -0.0018])

# %%
# linear regression model 
class LinearRegressionModel(torch.nn.Module):

    def __init__(self):
        super(LinearRegressionModel, self).__init__()
        self.linear = torch.nn.Linear(len(inputs[0]), 1)  # One in and one out

    def forward(self, x):
        y_pred = self.linear(x)
        return y_pred
    
linearmodel = LinearRegressionModel()
criterion = torch.nn.MSELoss()
optimizer = torch.optim.SGD(linearmodel.parameters(), lr=0.01)

for epoch in range(500):

    # Forward pass: Compute predicted y by passing 
    # x to the model
    pred_y = linearmodel(torch.Tensor(inputs_train))

    # Compute and print loss
    loss = criterion(pred_y, torch.Tensor(output_train))

    # Zero gradients, perform a backward pass, 
    # and update the weights.
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print('epoch {}, loss {}'.format(epoch, loss.item()))
# Out:
# /Users/katherinesong/UNH-Hackathon-2026-Group-3/.venv/lib/python3.14/site-packages/torch/nn/modules/loss.py:626: UserWarning: Using a target size (torch.Size([2356])) that is different to the input size (torch.Size([2356, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# epoch 0, loss 1.3971889019012451
# epoch 1, loss 1.3819156885147095
# epoch 2, loss 1.367242455482483
# epoch 3, loss 1.3531452417373657
# epoch 4, loss 1.3396011590957642
# epoch 5, loss 1.3265879154205322
# epoch 6, loss 1.314084529876709
# epoch 7, loss 1.3020706176757812
# epoch 8, loss 1.2905263900756836
# epoch 9, loss 1.2794334888458252
# epoch 10, loss 1.2687739133834839
# epoch 11, loss 1.2585301399230957
# epoch 12, loss 1.2486859560012817
# epoch 13, loss 1.2392252683639526
# epoch 14, loss 1.2301329374313354
# epoch 15, loss 1.2213943004608154
# epoch 16, loss 1.2129954099655151
# epoch 17, loss 1.2049227952957153
# epoch 18, loss 1.197163462638855
# epoch 19, loss 1.1897051334381104
# epoch 20, loss 1.1825358867645264
# epoch 21, loss 1.175644040107727
# epoch 22, loss 1.1690192222595215
# epoch 23, loss 1.1626503467559814
# epoch 24, loss 1.1565274000167847
# epoch 25, loss 1.1506409645080566
# epoch 26, loss 1.1449815034866333
# epoch 27, loss 1.139540195465088
# epoch 28, loss 1.1343084573745728
# epoch 29, loss 1.1292779445648193
# epoch 30, loss 1.1244409084320068
# epoch 31, loss 1.1197896003723145
# epoch 32, loss 1.1153167486190796
# epoch 33, loss 1.1110156774520874
# epoch 34, loss 1.1068793535232544
# epoch 35, loss 1.1029012203216553
# epoch 36, loss 1.0990755558013916
# epoch 37, loss 1.0953959226608276
# epoch 38, loss 1.091856837272644
# epoch 39, loss 1.0884528160095215
# epoch 40, loss 1.0851786136627197
# epoch 41, loss 1.0820292234420776
# epoch 42, loss 1.0789995193481445
# epoch 43, loss 1.0760852098464966
# epoch 44, loss 1.0732814073562622
# epoch 45, loss 1.0705842971801758
# epoch 46, loss 1.0679893493652344
# epoch 47, loss 1.065492868423462
# epoch 48, loss 1.0630909204483032
# epoch 49, loss 1.0607795715332031
# epoch 50, loss 1.0585556030273438
# epoch 51, loss 1.0564159154891968
# epoch 52, loss 1.0543568134307861
# epoch 53, loss 1.0523751974105835
# epoch 54, loss 1.0504682064056396
# epoch 55, loss 1.0486332178115845
# epoch 56, loss 1.0468668937683105
# epoch 57, loss 1.045167088508606
# epoch 58, loss 1.043531060218811
# epoch 59, loss 1.0419561862945557
# epoch 60, loss 1.040440559387207
# epoch 61, loss 1.0389814376831055
# epoch 62, loss 1.0375767946243286
# epoch 63, loss 1.0362247228622437
# epoch 64, loss 1.0349229574203491
# epoch 65, loss 1.0336699485778809
# epoch 66, loss 1.0324633121490479
# epoch 67, loss 1.031301736831665
# epoch 68, loss 1.0301830768585205
# epoch 69, loss 1.0291061401367188
# epoch 70, loss 1.028069019317627
# epoch 71, loss 1.02707040309906
# epoch 72, loss 1.026108741760254
# epoch 73, loss 1.0251824855804443
# epoch 74, loss 1.0242905616760254
# epoch 75, loss 1.023431420326233
# epoch 76, loss 1.022603988647461
# epoch 77, loss 1.021807074546814
# epoch 78, loss 1.021039366722107
# epoch 79, loss 1.0202999114990234
# epoch 80, loss 1.019587516784668
# epoch 81, loss 1.0189012289047241
# epoch 82, loss 1.018239974975586
# epoch 83, loss 1.0176030397415161
# epoch 84, loss 1.0169892311096191
# epoch 85, loss 1.0163979530334473
# epoch 86, loss 1.0158281326293945
# epoch 87, loss 1.0152791738510132
# epoch 88, loss 1.0147498846054077
# epoch 89, loss 1.014240026473999
# epoch 90, loss 1.0137486457824707
# epoch 91, loss 1.0132750272750854
# epoch 92, loss 1.0128185749053955
# epoch 93, loss 1.0123785734176636
# epoch 94, loss 1.0119543075561523
# epoch 95, loss 1.0115455389022827
# epoch 96, loss 1.0111513137817383
# epoch 97, loss 1.01077139377594
# epoch 98, loss 1.0104050636291504
# epoch 99, loss 1.0100518465042114
# epoch 100, loss 1.0097112655639648
# epoch 101, loss 1.0093828439712524
# epoch 102, loss 1.0090663433074951
# epoch 103, loss 1.0087608098983765
# epoch 104, loss 1.008466362953186
# epoch 105, loss 1.0081822872161865
# epoch 106, loss 1.0079083442687988
# epoch 107, loss 1.0076441764831543
# epoch 108, loss 1.0073891878128052
# epoch 109, loss 1.007143259048462
# epoch 110, loss 1.0069061517715454
# epoch 111, loss 1.006677269935608
# epoch 112, loss 1.0064564943313599
# epoch 113, loss 1.0062434673309326
# epoch 114, loss 1.0060380697250366
# epoch 115, loss 1.0058395862579346
# epoch 116, loss 1.0056482553482056
# epoch 117, loss 1.0054636001586914
# epoch 118, loss 1.0052852630615234
# epoch 119, loss 1.0051132440567017
# epoch 120, loss 1.0049470663070679
# epoch 121, loss 1.004786729812622
# epoch 122, loss 1.0046319961547852
# epoch 123, loss 1.004482626914978
# epoch 124, loss 1.0043383836746216
# epoch 125, loss 1.0041990280151367
# epoch 126, loss 1.0040645599365234
# epoch 127, loss 1.0039347410202026
# epoch 128, loss 1.0038093328475952
# epoch 129, loss 1.0036882162094116
# epoch 130, loss 1.0035712718963623
# epoch 131, loss 1.0034582614898682
# epoch 132, loss 1.0033491849899292
# epoch 133, loss 1.0032436847686768
# epoch 134, loss 1.0031418800354004
# epoch 135, loss 1.0030434131622314
# epoch 136, loss 1.0029484033584595
# epoch 137, loss 1.0028566122055054
# epoch 138, loss 1.0027676820755005
# epoch 139, loss 1.0026819705963135
# epoch 140, loss 1.0025991201400757
# epoch 141, loss 1.0025190114974976
# epoch 142, loss 1.0024415254592896
# epoch 143, loss 1.0023666620254517
# epoch 144, loss 1.0022943019866943
# epoch 145, loss 1.0022244453430176
# epoch 146, loss 1.0021566152572632
# epoch 147, loss 1.0020912885665894
# epoch 148, loss 1.0020281076431274
# epoch 149, loss 1.0019668340682983
# epoch 150, loss 1.0019077062606812
# epoch 151, loss 1.0018506050109863
# epoch 152, loss 1.0017951726913452
# epoch 153, loss 1.001741647720337
# epoch 154, loss 1.0016899108886719
# epoch 155, loss 1.001639723777771
# epoch 156, loss 1.0015913248062134
# epoch 157, loss 1.00154447555542
# epoch 158, loss 1.0014989376068115
# epoch 159, loss 1.0014550685882568
# epoch 160, loss 1.0014126300811768
# epoch 161, loss 1.0013713836669922
# epoch 162, loss 1.0013315677642822
# epoch 163, loss 1.0012929439544678
# epoch 164, loss 1.0012556314468384
# epoch 165, loss 1.001219630241394
# epoch 166, loss 1.0011845827102661
# epoch 167, loss 1.0011507272720337
# epoch 168, loss 1.0011178255081177
# epoch 169, loss 1.0010861158370972
# epoch 170, loss 1.0010552406311035
# epoch 171, loss 1.0010254383087158
# epoch 172, loss 1.0009965896606445
# epoch 173, loss 1.0009685754776
# epoch 174, loss 1.000941514968872
# epoch 175, loss 1.0009151697158813
# epoch 176, loss 1.000889778137207
# epoch 177, loss 1.00086510181427
# epoch 178, loss 1.0008410215377808
# epoch 179, loss 1.000817894935608
# epoch 180, loss 1.0007953643798828
# epoch 181, loss 1.000773549079895
# epoch 182, loss 1.000752568244934
# epoch 183, loss 1.0007319450378418
# epoch 184, loss 1.0007121562957764
# epoch 185, loss 1.0006928443908691
# epoch 186, loss 1.0006742477416992
# epoch 187, loss 1.0006561279296875
# epoch 188, loss 1.0006386041641235
# epoch 189, loss 1.0006214380264282
# epoch 190, loss 1.0006049871444702
# epoch 191, loss 1.0005888938903809
# epoch 192, loss 1.0005732774734497
# epoch 193, loss 1.0005581378936768
# epoch 194, loss 1.000543475151062
# epoch 195, loss 1.000529170036316
# epoch 196, loss 1.0005154609680176
# epoch 197, loss 1.0005019903182983
# epoch 198, loss 1.0004889965057373
# epoch 199, loss 1.000476360321045
# epoch 200, loss 1.000463843345642
# epoch 201, loss 1.0004520416259766
# epoch 202, loss 1.0004404783248901
# epoch 203, loss 1.0004291534423828
# epoch 204, loss 1.0004181861877441
# epoch 205, loss 1.0004075765609741
# epoch 206, loss 1.0003972053527832
# epoch 207, loss 1.000387191772461
# epoch 208, loss 1.0003775358200073
# epoch 209, loss 1.0003681182861328
# epoch 210, loss 1.0003588199615479
# epoch 211, loss 1.0003498792648315
# epoch 212, loss 1.0003411769866943
# epoch 213, loss 1.0003327131271362
# epoch 214, loss 1.0003244876861572
# epoch 215, loss 1.0003165006637573
# epoch 216, loss 1.0003087520599365
# epoch 217, loss 1.0003011226654053
# epoch 218, loss 1.0002938508987427
# epoch 219, loss 1.00028657913208
# epoch 220, loss 1.0002797842025757
# epoch 221, loss 1.0002729892730713
# epoch 222, loss 1.0002663135528564
# epoch 223, loss 1.0002599954605103
# epoch 224, loss 1.0002537965774536
# epoch 225, loss 1.0002474784851074
# epoch 226, loss 1.000241756439209
# epoch 227, loss 1.000235915184021
# epoch 228, loss 1.0002304315567017
# epoch 229, loss 1.0002249479293823
# epoch 230, loss 1.0002195835113525
# epoch 231, loss 1.0002143383026123
# epoch 232, loss 1.0002093315124512
# epoch 233, loss 1.0002044439315796
# epoch 234, loss 1.0001996755599976
# epoch 235, loss 1.000195026397705
# epoch 236, loss 1.0001906156539917
# epoch 237, loss 1.0001862049102783
# epoch 238, loss 1.0001819133758545
# epoch 239, loss 1.0001777410507202
# epoch 240, loss 1.000173568725586
# epoch 241, loss 1.0001696348190308
# epoch 242, loss 1.0001657009124756
# epoch 243, loss 1.0001620054244995
# epoch 244, loss 1.0001583099365234
# epoch 245, loss 1.0001546144485474
# epoch 246, loss 1.00015127658844
# epoch 247, loss 1.000147819519043
# epoch 248, loss 1.0001444816589355
# epoch 249, loss 1.0001412630081177
# epoch 250, loss 1.0001380443572998
# epoch 251, loss 1.000135064125061
# epoch 252, loss 1.0001319646835327
# epoch 253, loss 1.0001291036605835
# epoch 254, loss 1.0001262426376343
# epoch 255, loss 1.000123381614685
# epoch 256, loss 1.000120759010315
# epoch 257, loss 1.0001180171966553
# epoch 258, loss 1.0001153945922852
# epoch 259, loss 1.0001128911972046
# epoch 260, loss 1.000110387802124
# epoch 261, loss 1.0001081228256226
# epoch 262, loss 1.000105619430542
# epoch 263, loss 1.0001033544540405
# epoch 264, loss 1.0001012086868286
# epoch 265, loss 1.0000989437103271
# epoch 266, loss 1.0000967979431152
# epoch 267, loss 1.0000946521759033
# epoch 268, loss 1.0000927448272705
# epoch 269, loss 1.0000908374786377
# epoch 270, loss 1.0000886917114258
# epoch 271, loss 1.0000869035720825
# epoch 272, loss 1.0000849962234497
# epoch 273, loss 1.0000832080841064
# epoch 274, loss 1.0000814199447632
# epoch 275, loss 1.00007963180542
# epoch 276, loss 1.0000779628753662
# epoch 277, loss 1.000076413154602
# epoch 278, loss 1.0000747442245483
# epoch 279, loss 1.0000731945037842
# epoch 280, loss 1.00007164478302
# epoch 281, loss 1.0000702142715454
# epoch 282, loss 1.0000686645507812
# epoch 283, loss 1.0000672340393066
# epoch 284, loss 1.000065803527832
# epoch 285, loss 1.000064492225647
# epoch 286, loss 1.000063180923462
# epoch 287, loss 1.0000617504119873
# epoch 288, loss 1.0000605583190918
# epoch 289, loss 1.0000593662261963
# epoch 290, loss 1.0000580549240112
# epoch 291, loss 1.0000569820404053
# epoch 292, loss 1.0000556707382202
# epoch 293, loss 1.0000545978546143
# epoch 294, loss 1.0000534057617188
# epoch 295, loss 1.0000524520874023
# epoch 296, loss 1.0000513792037964
# epoch 297, loss 1.0000501871109009
# epoch 298, loss 1.0000492334365845
# epoch 299, loss 1.000048279762268
# epoch 300, loss 1.000047206878662
# epoch 301, loss 1.0000462532043457
# epoch 302, loss 1.0000452995300293
# epoch 303, loss 1.0000444650650024
# epoch 304, loss 1.0000436305999756
# epoch 305, loss 1.0000426769256592
# epoch 306, loss 1.0000418424606323
# epoch 307, loss 1.0000410079956055
# epoch 308, loss 1.000040054321289
# epoch 309, loss 1.0000392198562622
# epoch 310, loss 1.000038504600525
# epoch 311, loss 1.0000377893447876
# epoch 312, loss 1.0000370740890503
# epoch 313, loss 1.0000362396240234
# epoch 314, loss 1.0000355243682861
# epoch 315, loss 1.0000348091125488
# epoch 316, loss 1.0000340938568115
# epoch 317, loss 1.0000333786010742
# epoch 318, loss 1.0000327825546265
# epoch 319, loss 1.0000320672988892
# epoch 320, loss 1.0000314712524414
# epoch 321, loss 1.0000309944152832
# epoch 322, loss 1.000030279159546
# epoch 323, loss 1.0000296831130981
# epoch 324, loss 1.0000290870666504
# epoch 325, loss 1.0000284910202026
# epoch 326, loss 1.0000278949737549
# epoch 327, loss 1.0000274181365967
# epoch 328, loss 1.000026822090149
# epoch 329, loss 1.0000263452529907
# epoch 330, loss 1.000025749206543
# epoch 331, loss 1.0000252723693848
# epoch 332, loss 1.0000249147415161
# epoch 333, loss 1.0000243186950684
# epoch 334, loss 1.0000238418579102
# epoch 335, loss 1.000023365020752
# epoch 336, loss 1.0000230073928833
# epoch 337, loss 1.000022530555725
# epoch 338, loss 1.0000219345092773
# epoch 339, loss 1.0000215768814087
# epoch 340, loss 1.00002121925354
# epoch 341, loss 1.0000207424163818
# epoch 342, loss 1.0000203847885132
# epoch 343, loss 1.0000200271606445
# epoch 344, loss 1.0000195503234863
# epoch 345, loss 1.0000191926956177
# epoch 346, loss 1.0000189542770386
# epoch 347, loss 1.0000184774398804
# epoch 348, loss 1.0000181198120117
# epoch 349, loss 1.0000178813934326
# epoch 350, loss 1.000017523765564
# epoch 351, loss 1.0000171661376953
# epoch 352, loss 1.0000168085098267
# epoch 353, loss 1.000016450881958
# epoch 354, loss 1.0000160932540894
# epoch 355, loss 1.0000158548355103
# epoch 356, loss 1.0000154972076416
# epoch 357, loss 1.0000152587890625
# epoch 358, loss 1.0000149011611938
# epoch 359, loss 1.0000145435333252
# epoch 360, loss 1.0000144243240356
# epoch 361, loss 1.000014066696167
# epoch 362, loss 1.000013828277588
# epoch 363, loss 1.0000135898590088
# epoch 364, loss 1.0000133514404297
# epoch 365, loss 1.000012993812561
# epoch 366, loss 1.000012755393982
# epoch 367, loss 1.0000125169754028
# epoch 368, loss 1.0000122785568237
# epoch 369, loss 1.0000120401382446
# epoch 370, loss 1.000011920928955
# epoch 371, loss 1.0000115633010864
# epoch 372, loss 1.0000114440917969
# epoch 373, loss 1.0000112056732178
# epoch 374, loss 1.0000109672546387
# epoch 375, loss 1.0000107288360596
# epoch 376, loss 1.0000104904174805
# epoch 377, loss 1.000010371208191
# epoch 378, loss 1.0000101327896118
# epoch 379, loss 1.0000100135803223
# epoch 380, loss 1.0000097751617432
# epoch 381, loss 1.000009536743164
# epoch 382, loss 1.0000094175338745
# epoch 383, loss 1.0000091791152954
# epoch 384, loss 1.0000090599060059
# epoch 385, loss 1.0000088214874268
# epoch 386, loss 1.0000087022781372
# epoch 387, loss 1.0000087022781372
# epoch 388, loss 1.000008463859558
# epoch 389, loss 1.0000083446502686
# epoch 390, loss 1.0000081062316895
# epoch 391, loss 1.0000078678131104
# epoch 392, loss 1.0000077486038208
# epoch 393, loss 1.0000076293945312
# epoch 394, loss 1.0000075101852417
# epoch 395, loss 1.0000072717666626
# epoch 396, loss 1.000007152557373
# epoch 397, loss 1.0000070333480835
# epoch 398, loss 1.000006914138794
# epoch 399, loss 1.0000067949295044
# epoch 400, loss 1.0000066757202148
# epoch 401, loss 1.0000065565109253
# epoch 402, loss 1.0000064373016357
# epoch 403, loss 1.0000063180923462
# epoch 404, loss 1.0000061988830566
# epoch 405, loss 1.000006079673767
# epoch 406, loss 1.0000059604644775
# epoch 407, loss 1.000005841255188
# epoch 408, loss 1.0000057220458984
# epoch 409, loss 1.0000056028366089
# epoch 410, loss 1.0000056028366089
# epoch 411, loss 1.0000053644180298
# epoch 412, loss 1.0000053644180298
# epoch 413, loss 1.0000052452087402
# epoch 414, loss 1.0000050067901611
# epoch 415, loss 1.0000050067901611
# epoch 416, loss 1.0000048875808716
# epoch 417, loss 1.0000048875808716
# epoch 418, loss 1.0000046491622925
# epoch 419, loss 1.0000046491622925
# epoch 420, loss 1.000004529953003
# epoch 421, loss 1.000004529953003
# epoch 422, loss 1.0000042915344238
# epoch 423, loss 1.0000042915344238
# epoch 424, loss 1.0000042915344238
# epoch 425, loss 1.0000041723251343
# epoch 426, loss 1.0000039339065552
# epoch 427, loss 1.0000039339065552
# epoch 428, loss 1.0000039339065552
# epoch 429, loss 1.0000038146972656
# epoch 430, loss 1.0000038146972656
# epoch 431, loss 1.000003695487976
# epoch 432, loss 1.0000035762786865
# epoch 433, loss 1.0000035762786865
# epoch 434, loss 1.000003457069397
# epoch 435, loss 1.000003457069397
# epoch 436, loss 1.0000033378601074
# epoch 437, loss 1.0000033378601074
# epoch 438, loss 1.0000032186508179
# epoch 439, loss 1.0000032186508179
# epoch 440, loss 1.0000030994415283
# epoch 441, loss 1.0000030994415283
# epoch 442, loss 1.0000030994415283
# epoch 443, loss 1.0000029802322388
# epoch 444, loss 1.0000028610229492
# epoch 445, loss 1.0000028610229492
# epoch 446, loss 1.0000028610229492
# epoch 447, loss 1.0000028610229492
# epoch 448, loss 1.0000027418136597
# epoch 449, loss 1.0000027418136597
# epoch 450, loss 1.0000027418136597
# epoch 451, loss 1.0000025033950806
# epoch 452, loss 1.0000025033950806
# epoch 453, loss 1.000002384185791
# epoch 454, loss 1.000002384185791
# epoch 455, loss 1.000002384185791
# epoch 456, loss 1.000002384185791
# epoch 457, loss 1.0000022649765015
# epoch 458, loss 1.0000022649765015
# epoch 459, loss 1.000002145767212
# epoch 460, loss 1.000002145767212
# epoch 461, loss 1.000002145767212
# epoch 462, loss 1.000002145767212
# epoch 463, loss 1.0000020265579224
# epoch 464, loss 1.0000020265579224
# epoch 465, loss 1.0000020265579224
# epoch 466, loss 1.0000019073486328
# epoch 467, loss 1.0000019073486328
# epoch 468, loss 1.0000019073486328
# epoch 469, loss 1.0000017881393433
# epoch 470, loss 1.0000017881393433
# epoch 471, loss 1.0000017881393433
# epoch 472, loss 1.0000017881393433
# epoch 473, loss 1.0000016689300537
# epoch 474, loss 1.0000016689300537
# epoch 475, loss 1.0000016689300537
# epoch 476, loss 1.0000016689300537
# epoch 477, loss 1.0000016689300537
# epoch 478, loss 1.0000015497207642
# epoch 479, loss 1.0000014305114746
# epoch 480, loss 1.0000014305114746
# epoch 481, loss 1.0000014305114746
# epoch 482, loss 1.0000014305114746
# epoch 483, loss 1.0000014305114746
# epoch 484, loss 1.0000014305114746
# epoch 485, loss 1.0000014305114746
# epoch 486, loss 1.000001311302185
# epoch 487, loss 1.000001311302185
# epoch 488, loss 1.000001311302185
# epoch 489, loss 1.000001311302185
# epoch 490, loss 1.000001311302185
# epoch 491, loss 1.000001311302185
# epoch 492, loss 1.0000011920928955
# epoch 493, loss 1.0000011920928955
# epoch 494, loss 1.0000011920928955
# epoch 495, loss 1.000001072883606
# epoch 496, loss 1.000001072883606
# epoch 497, loss 1.000001072883606
# epoch 498, loss 1.000001072883606
# epoch 499, loss 1.000001072883606

# %% [markdown]
# # torch.nn

# %%
class NNmodel(nn.Module):
    def __init__ (self):
        super().__init__()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(len(inputs_train[0]), 64),
            nn.BatchNorm1d(64), 
            nn.ReLU(),

            nn.Linear(64, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(128, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(64, 32),
            nn.ReLU(),

            nn.Linear(32, 1)

        )

    def forward(self, x):
        # logits = self.linear_relu_stack(x)
        return self.linear_relu_stack(x)
    
class AbsDataset(Dataset):
    def __init__ (self, inputs, output):
        self.input_tensor = torch.tensor(inputs).float() 
        self.output_tensor = torch.tensor(output).float()
        
    def __len__(self):
        return len(self.output_tensor)
    
    def __getitem__(self, idx):
        return self.input_tensor[idx], self.output_tensor[idx]

# %%
train_dataset = AbsDataset(inputs_train, output_train)
test_dataset = AbsDataset(inputs_test, output_test)

# shuffles and batches 
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# initiate model
nnmodel = NNmodel()
loss_func = nn.MSELoss()
optimizer = torch.optim.Adam(nnmodel.parameters(), lr=0.001) # learning rate

# %%
# training with per-epoch testing
training_loss_ls = []
test_loss_ls = []

epochs = 100

for epoch in range(epochs):
    epoch_loss_ls = []
    print("epoch #:", epoch)

    # training loop 
    nnmodel.train()
    for data, labels in train_loader:
        optimizer.zero_grad() # resets gradients in optimizer to 0 
        outputs = nnmodel(data)

        # calculate loss function (MSE)
        loss = loss_func(outputs, labels.unsqueeze(1))
        epoch_loss_ls.append(loss.item())
        loss.backward() # back prop 

        # optimizer 
        optimizer.step() # updates all parameters via gradient descent 
        
    avg_loss = np.average(np.array(epoch_loss_ls))
    print("average training loss:", avg_loss)
    training_loss_ls.append(avg_loss)
    
    # testing loop per epoch
    nnmodel.eval()
    test_epoch_ls = []
    with torch.no_grad():
        for data, labels in test_loader:
            outputs = nnmodel(data)
            loss = loss_func(outputs, labels)
            test_epoch_ls.append(loss.item())
    
    avg_test_loss = np.average(np.array(test_epoch_ls))
    print("average test loss:", avg_test_loss)
    test_loss_ls.append(avg_test_loss)
# Out:
# epoch #: 0
# average training loss: 0.5847081763518823
# average test loss: 0.22008600497293568
# epoch #: 1
# average training loss: 0.24425341954102386
# /Users/katherinesong/UNH-Hackathon-2026-Group-3/.venv/lib/python3.14/site-packages/torch/nn/modules/loss.py:626: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# average test loss: 0.16295269720756955
# epoch #: 2
# average training loss: 0.18008920912807053
# average test loss: 0.1429590950798562
# epoch #: 3
# average training loss: 0.16921910844944618
# average test loss: 0.13494169223143573
# epoch #: 4
# average training loss: 0.14497111475950963
# average test loss: 0.1260425593467585
# epoch #: 5
# average training loss: 0.14941674088304108
# average test loss: 0.12258852349569671
# epoch #: 6
# average training loss: 0.13220540011251294
# average test loss: 0.114311806673266
# epoch #: 7
# average training loss: 0.13511327633986603
# average test loss: 0.11968638454171363
# epoch #: 8
# average training loss: 0.13160186643536026
# average test loss: 0.12666765644239036
# epoch #: 9
# average training loss: 0.11574724417280506
# average test loss: 0.11391642491386608
# epoch #: 10
# average training loss: 0.11122533578324963
# average test loss: 0.10877124619485905
# epoch #: 11
# average training loss: 0.11253096243819675
# average test loss: 0.11069425135116064
# epoch #: 12
# average training loss: 0.11688012166603191
# average test loss: 0.10844509401968312
# epoch #: 13
# average training loss: 0.10715393691852286
# average test loss: 0.11407040279318638
# epoch #: 14
# average training loss: 0.1010408043055921
# average test loss: 0.11322674413106917
# epoch #: 15
# average training loss: 0.09512493245907731
# average test loss: 0.10803259322988223
# epoch #: 16
# average training loss: 0.1045600512140506
# average test loss: 0.10714027044957126
# epoch #: 17
# average training loss: 0.10299754817340825
# average test loss: 0.11433233205737424
# epoch #: 18
# average training loss: 0.1005207485443837
# average test loss: 0.10646594731823728
# epoch #: 19
# average training loss: 0.09832232334726565
# average test loss: 0.1085979616260924
# epoch #: 20
# average training loss: 0.09188587812555803
# average test loss: 0.11602066751684831
# epoch #: 21
# average training loss: 0.08973754147017324
# average test loss: 0.11420837240672643
# epoch #: 22
# average training loss: 0.0910535267478711
# average test loss: 0.11027258111476011
# epoch #: 23
# average training loss: 0.0985639330905837
# average test loss: 0.1107650807873346
# epoch #: 24
# average training loss: 0.09002280396384162
# average test loss: 0.11214831926530758
# epoch #: 25
# average training loss: 0.09118343909849992
# average test loss: 0.1121602776046828
# epoch #: 26
# average training loss: 0.08841999298011935
# average test loss: 0.1178925480415502
# epoch #: 27
# average training loss: 0.08322782170128178
# average test loss: 0.11263442699095084
# epoch #: 28
# average training loss: 0.08322244832241857
# average test loss: 0.11543153479619132
# epoch #: 29
# average training loss: 0.0802211190599042
# average test loss: 0.11502958823865152
# epoch #: 30
# average training loss: 0.08034295598800117
# average test loss: 0.1160714652479995
# epoch #: 31
# average training loss: 0.08097904517843917
# average test loss: 0.1128169754662438
# epoch #: 32
# average training loss: 0.0850285847444792
# average test loss: 0.11186112272561376
# epoch #: 33
# average training loss: 0.09217555820941925
# average test loss: 0.12896346081526486
# epoch #: 34
# average training loss: 0.08317257765982602
# average test loss: 0.11210022474720464
# epoch #: 35
# average training loss: 0.07786265086080577
# average test loss: 0.11079302236011242
# epoch #: 36
# average training loss: 0.07966273348476435
# average test loss: 0.1193790544332441
# epoch #: 37
# average training loss: 0.07755922123387053
# average test loss: 0.11595309236450659
# epoch #: 38
# average training loss: 0.08376532430584366
# average test loss: 0.11263294314354476
# epoch #: 39
# average training loss: 0.07362270566660005
# average test loss: 0.11609011375905774
# epoch #: 40
# average training loss: 0.08228421060217393
# average test loss: 0.11295828735741457
# epoch #: 41
# average training loss: 0.07581057510263212
# average test loss: 0.11877908044212541
# epoch #: 42
# average training loss: 0.07265396466529048
# average test loss: 0.1188052206347038
# epoch #: 43
# average training loss: 0.07082166361647683
# average test loss: 0.11320870759795584
# epoch #: 44
# average training loss: 0.0718309401056251
# average test loss: 0.11491904989668378
# epoch #: 45
# average training loss: 0.06841020427040152
# average test loss: 0.11635332603500988
# epoch #: 46
# average training loss: 0.07919745056613071
# average test loss: 0.11380233227881904
# epoch #: 47
# average training loss: 0.07948534160449698
# average test loss: 0.11819434775606324
# epoch #: 48
# average training loss: 0.07304201496613992
# average test loss: 0.1271526726043893
# epoch #: 49
# average training loss: 0.07003949965174133
# average test loss: 0.1173576652253043
# epoch #: 50
# average training loss: 0.0748216044661161
# average test loss: 0.1232094503478182
# epoch #: 51
# average training loss: 0.07544969304187878
# average test loss: 0.11773277087132088
# epoch #: 52
# average training loss: 0.06865395565290709
# average test loss: 0.11459093763483223
# epoch #: 53
# average training loss: 0.07658912075331083
# average test loss: 0.1150598283199288
# epoch #: 54
# average training loss: 0.07034734571100892
# average test loss: 0.12080424209909345
# epoch #: 55
# average training loss: 0.06701399526886039
# average test loss: 0.1186793929921372
# epoch #: 56
# average training loss: 0.06979511617808729
# average test loss: 0.11891417226612289
# epoch #: 57
# average training loss: 0.07004559714649175
# average test loss: 0.11923043690313719
# epoch #: 58
# average training loss: 0.06139929230148728
# average test loss: 0.11679421358753127
# epoch #: 59
# average training loss: 0.06446139202327342
# average test loss: 0.11414831346797429
# epoch #: 60
# average training loss: 0.07445944221438588
# average test loss: 0.12249131628675945
# epoch #: 61
# average training loss: 0.06341840699315071
# average test loss: 0.12857936419563543
# epoch #: 62
# average training loss: 0.0621005365171948
# average test loss: 0.12452984011050076
# epoch #: 63
# average training loss: 0.06183066969183651
# average test loss: 0.12274325642828629
# epoch #: 64
# average training loss: 0.0735211266154373
# average test loss: 0.11870264222133312
# epoch #: 65
# average training loss: 0.06914305495651993
# average test loss: 0.12267292257867816
# epoch #: 66
# average training loss: 0.06118456938782254
# average test loss: 0.12178698353110748
# epoch #: 67
# average training loss: 0.06618192661050204
# average test loss: 0.11737966011953847
# epoch #: 68
# average training loss: 0.07217691863912183
# average test loss: 0.11467946862487752
# epoch #: 69
# average training loss: 0.06369198677507606
# average test loss: 0.1269278498447862
# epoch #: 70
# average training loss: 0.055212124779417705
# average test loss: 0.1235658029914238
# epoch #: 71
# average training loss: 0.06150018302975474
# average test loss: 0.12387785146874417
# epoch #: 72
# average training loss: 0.06639825472155132
# average test loss: 0.12899172067991233
# epoch #: 73
# average training loss: 0.0616032616612879
# average test loss: 0.1266205071345668
# epoch #: 74
# average training loss: 0.060082014952156995
# average test loss: 0.11732198526940599
# epoch #: 75
# average training loss: 0.06428196658757893
# average test loss: 0.1219834123118868
# epoch #: 76
# average training loss: 0.07523789659545228
# average test loss: 0.12585909720536556
# epoch #: 77
# average training loss: 0.06231967223858511
# average test loss: 0.12464443810831628
# epoch #: 78
# average training loss: 0.05169613095554146
# average test loss: 0.13032693052765118
# epoch #: 79
# average training loss: 0.05915018402644106
# average test loss: 0.12103532955999786
# epoch #: 80
# average training loss: 0.05953385998067018
# average test loss: 0.12309700390616518
# epoch #: 81
# average training loss: 0.054129870356740176
# average test loss: 0.12498323109255828
# epoch #: 82
# average training loss: 0.05341983440558653
# average test loss: 0.12020116863945192
# epoch #: 83
# average training loss: 0.06440931362276142
# average test loss: 0.12274809077144828
# epoch #: 84
# average training loss: 0.06211142493663607
# average test loss: 0.11947923717393064
# epoch #: 85
# average training loss: 0.057209386263747476
# average test loss: 0.1177381397092678
# epoch #: 86
# average training loss: 0.06006157297540356
# average test loss: 0.12663384913745
# epoch #: 87
# average training loss: 0.0591125094105263
# average test loss: 0.1278409395620937
# epoch #: 88
# average training loss: 0.060936122377579276
# average test loss: 0.12217700054851137
# epoch #: 89
# average training loss: 0.05280776357127202
# average test loss: 0.12395547823131262
# epoch #: 90
# average training loss: 0.056039846628098876
# average test loss: 0.1307375036243556
# epoch #: 91
# average training loss: 0.05906749436178723
# average test loss: 0.12914616708892274
# epoch #: 92
# average training loss: 0.0531844497733825
# average test loss: 0.13014790340440574
# epoch #: 93
# average training loss: 0.0508775217206897
# average test loss: 0.1293062664417235
# epoch #: 94
# average training loss: 0.05432465893996728
# average test loss: 0.12632274803331306
# epoch #: 95
# average training loss: 0.05903454391738853
# average test loss: 0.12631297276918832
# epoch #: 96
# average training loss: 0.052824240228211555
# average test loss: 0.12334625762089939
# epoch #: 97
# average training loss: 0.059480718966271426
# average test loss: 0.12036741279059472
# epoch #: 98
# average training loss: 0.04880375545975324
# average test loss: 0.12765619402823283
# epoch #: 99
# average training loss: 0.06555883228980205
# average test loss: 0.1266286563118942

# %%
# Plot training and test loss together
x = range(epochs)
plt.figure(figsize=(10, 6))
plt.plot(x, training_loss_ls, label='Training Loss')
plt.plot(x, test_loss_ls, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training vs Test Loss')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## visualizing the model

# %%
# Visualize nn model: 2D plots of each input vs output
nnmodel.eval() # Set model to evaluation mode

fig, axes = plt.subplots(4, 6, figsize=(15, 10))
axes = axes.flatten()

# For each input variable, create predictions while varying that input
for i, ax in enumerate(axes):
    # Create a range of values for the input variable
    input_range = np.linspace(-4, 4, 100)
    
    # Create prediction arrays by holding other inputs at their mean
    predictions = []
    
    for val in input_range:
        # Start with mean normalized values for all inputs
        input_vector = np.mean(inputs_train, axis=0) # should be around zero 
        
        # Vary the current input
        input_vector[i] = val
        
        # Convert to tensor and predict
        input_tensor = torch.tensor(input_vector).float().unsqueeze(0)
        with torch.no_grad():
            pred = nnmodel(input_tensor).item()
        predictions.append(pred)
    
    # Plot
    ax.plot(input_range, predictions, linewidth=2, color='steelblue')
    ax.set_xlabel(input_columns[i], fontsize=11)
    ax.grid(True, alpha=0.3)

plt.suptitle('NN Model Financial Loss Predictions by Input Variable \n Standardized Scale', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# plots of unstandardized predictions vs unstandardized inputs 
nnmodel.eval()
fig, axes = plt.subplots(4, 6, figsize=(15, 10))
axes = axes.flatten()

# For each input variable, create predictions while varying that input
for i, ax in enumerate(axes):
    # Create a range of values for the input variable
    input_range = np.linspace(-2.5, 3, 100)
    
    # Create prediction arrays by holding other inputs at their mean
    predictions = []
    
    for val in input_range:
        # Start with mean normalized values for all inputs
        input_vector = np.mean(inputs_train, axis=0) # should be around zero 
        
        # Vary the current input
        input_vector[i] = val
        
        # Convert to tensor and predict
        input_tensor = torch.tensor(input_vector).float().unsqueeze(0)
        with torch.no_grad():
            pred = nnmodel(input_tensor).item()
        predictions.append(pred)

    # unstandardize 
    input_range = input_range * train_input_stds[i] + train_input_means[i]
    predictions = np.array(predictions) * train_output_std + train_output_mean

    # Plot
    ax.plot(input_range, predictions, linewidth=2, color='steelblue')
    ax.set_xlabel(input_columns[i], fontsize=11)
    ax.grid(True, alpha=0.3)

plt.suptitle('NN Model Financial Loss Predictions by Input Variable \n Unstandardized Scale', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Create 2D heatmaps for key input pairs
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()

input_names = [
    'satellite coverage score',
    'enemy_unit_count',
    'Enemy.Capability.Index',
    'Theater Distance KM'
]

# Define pairs to visualize (most important interactions)
pairs = [(0, 1), (0, 3), (2, 3), (1, 2)]

for plot_idx, (i, j) in enumerate(pairs):
    ax = axes[plot_idx]
    
    # Create grid of values
    input_range = np.linspace(-5, 5, 50)
    heatmap = np.zeros((len(input_range), len(input_range)))
    
    # Fill heatmap by varying inputs i and j
    for x_idx, x_val in enumerate(input_range):
        for y_idx, y_val in enumerate(input_range):
            input_vector = np.mean(inputs_train, axis=0)
            input_vector[input_columns.index(input_names[i])] = x_val
            input_vector[input_columns.index(input_names[j])] = y_val
            
            input_tensor = torch.tensor(input_vector).float().unsqueeze(0)
            with torch.no_grad():
                pred = nnmodel(input_tensor).item()
            heatmap[y_idx, x_idx] = pred
    
    # Plot heatmap with color scale
    im = ax.imshow(heatmap, aspect='auto', origin='lower', cmap='viridis')
    ax.set_xlabel(input_names[i], fontsize=11)
    ax.set_ylabel(input_names[j], fontsize=11)
    ax.set_title(f'{input_names[i]} vs {input_names[j]}', fontsize=12, fontweight='bold')
    
    # Add colorbar
    cbar = plt.colorbar(im, ax=ax)
    cbar.set_label('Normalized Financial Loss')

plt.suptitle('NN Model Standardized Input Variable Heatmaps', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
def calculate_metrics(true_values, predictions):
    mae = mean_absolute_error(true_values, predictions)
    r2 = r2_score(true_values, predictions)
    rmse = np.sqrt(mean_squared_error(true_values, predictions))

    mae = mean_absolute_error(true_values, predictions)
    r2 = r2_score(true_values, predictions)
    rmse = np.sqrt(mean_squared_error(true_values, predictions))
    mape = np.mean(np.abs((true_values - predictions) / true_values)) * 100

    print(f"Mean Absolute Error (MAE): {mae:.6f}")
    print(f"Root Mean Squared Error (RMSE): {rmse:.6f}")
    print(f"R² Score: {r2:.6f}")
    print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")  
    return mae, r2, rmse, mape

# %%
nnmodel.eval()

predictions = []
true_values = []

# calculate mean square error on train dataset 
with torch.no_grad():
    for data, labels in DataLoader(test_dataset, batch_size=32):
        outputs = nnmodel(data)
        predictions.extend(outputs.numpy().flatten())
        true_values.extend(labels.numpy().flatten())

predictions = np.array(predictions)
true_values = np.array(true_values)

# Calculate metrics
calculate_metrics(true_values, predictions)
# Out:
# Mean Absolute Error (MAE): 0.241541
# Root Mean Squared Error (RMSE): 0.355849
# R² Score: 0.874139
# Mean Absolute Percentage Error (MAPE): 82.27%
# (0.24154119193553925,
#  0.8741385340690613,
#  np.float64(0.35584924057432854),
#  np.float32(82.2748))

# %%
# calculate metrics on original (unstandardized) scale
predictions_unstd = predictions * (train_output_std) + train_output_mean
true_values_unstd = true_values * (train_output_std) + train_output_mean

# Calculate metrics
calculate_metrics(true_values_unstd, predictions_unstd)
# Out:
# Mean Absolute Error (MAE): 20.835884
# Root Mean Squared Error (RMSE): 30.696352
# R² Score: 0.874139
# Mean Absolute Percentage Error (MAPE): 6.53%
# (20.835884290233167,
#  0.8741385474145313,
#  np.float64(30.696351916299026),
#  np.float64(6.5330920092572144))
